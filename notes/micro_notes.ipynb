# %%
# Out:
# 15
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 162
#     160 if __name__ == '__main__':
#     161     runner = unittest.TextTestRunner()
# --> 162     runner.run(suite())
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/pyenv_spx/lib/python3.11/unittest/runner.py:217, in TextTestRunner.run(self, test)
#     215     startTestRun()
#     216 try:
# --> 217     test(result)
#     218 finally:
#     219     stopTestRun = getattr(result, 'stopTestRun', None)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/pyenv_spx/lib/python3.11/unittest/suite.py:84, in BaseTestSuite.__call__(self, *args, **kwds)
#      83 def __call__(self, *args, **kwds):
# ---> 84     return self.run(*args, **kwds)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/pyenv_spx/lib/python3.11/unittest/suite.py:122, in TestSuite.run(self, result, debug)
#     119         continue
# ...
